# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/dhirajnitk/Keras-HDF5-/blob/master/test/DeepLearning_3.ipynb)

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !ls -lat ~/.gdfuse/default/config
#!cp ~/.gdfuse/default/config /content/drive
# Out:
# -rw-r--r-- 1 root root 1055 Jun 11 08:43 /content/.gdfuse/default/config

# %%
# !ls
# !mkdir -p drive
# !google-drive-ocamlfuse drive
#!cp ~/.gdfuse/default/config /content/drive
# !ls
# Out:
# datalab  drive
# datalab  drive

# %%
# !ls /content/drive/KerasDeepNet/hackerearth
# Out:
# attributes.txt	classes.txt  meta-data.rar  test_img.rar  train_img.rar

# %%
#No need once you have added shared files inside your directory
#unmount and Copy config file. shared_with_me=true must be set in config to see all third party shared files in read only mode 
# !cp  /content/drive/config ~/.gdfuse/default/config
# !fusermount -u drive
# !google-drive-ocamlfuse  drive
# !ls /content/drive
# Out:
# total 6547532
# drwxr-xr-x 2 root root       4096 Jun  1 19:15 ..
# -r--r--r-- 1 root root 4705200243 Apr 19 03:13 train_img.rar
# -r--r--r-- 1 root root 1999226981 Apr 19 00:32 test_img.rar
# dr-xr-xr-x 2 root root       4096 Apr 18 23:45 .
# -r--r--r-- 1 root root     233101 Apr 18 23:45 meta-data.rar
# -r--r--r-- 1 root root       1205 Apr 18 23:44 attributes.txt
# -r--r--r-- 1 root root        755 Apr 18 23:44 classes.txt

# %%
# !apt-get install unrar
# !pip install tqdm
# !pip install h5py_cache
#import keras
#print(keras.__version__)
#print(keras.__file__)
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   unrar
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 129 kB of archives.
# After this operation, 322 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 unrar amd64 1:5.5.8-1 [129 kB]
# Fetched 129 kB in 0s (1,409 kB/s)
# Selecting previously unselected package unrar.
# (Reading database ... 19735 files and directories currently installed.)
# Preparing to unpack .../unrar_1%3a5.5.8-1_amd64.deb ...
# Unpacking unrar (1:5.5.8-1) ...
# Setting up unrar (1:5.5.8-1) ...
# update-alternatives: using /usr/bin/unrar-nonfree to provide /usr/bin/unrar (unrar) in auto mode
# ...
#     100% |████████████████████████████████| 51kB 3.9MB/s
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/f0/ce/3e/40128ad3a26c4737100842671c7006428f83b328232c210569
# ...

# %%
#!which python3
#import keras
#print(keras.__version__)
#!pip show --verbose keras
! ls /dev/full
#!find / -type f -name 'image.py'
# Out:
# /dev/full

# %%
#!which python

# !rm -rf /usr/local/lib/python3.6/dist-packages/keras/preprocessing/__pycache__/training.cpython-36.pyc
# !rm -rf /usr/local/lib/python3.6/dist-packages/keras/engine/__pycache__/image.cpython-36.pyc
# !rm -rf /usr/local/lib/python3.6/dist-packages/keras/engine/training.py
#!cp -r /content/drive/KerasDeepNet/image.py /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image.py
# !cp -r /content/drive/KerasDeepNet/image.py /usr/local/lib/python3.6/dist-packages/keras/preprocessing
# !cp -r /content/drive/KerasDeepNet/training.py /usr/local/lib/python3.6/dist-packages/keras/engine
#!cat /usr/local/lib/python3.6/dist-packages/keras/preprocessing/image.py

# %%
#!which python3
#import keras
#print(keras.__version__)
#!pip show --verbose keras
#! ls /
#!find / -type f -name 'image.py'
#!find / -type f -name 'training.py'
#!find / -type f -name 'image.py'
#!find / -type f -name 'image.cpython-36.pyc' | xargs rm
#!find / -type f -name 'image.cpython-36.pyc'
#!rm -rf /usr/local/lib/python3.6/dist-packages/keras_preprocessing
#!rm -rf /usr/local/lib/python3.6/dist-packages/keras
#!rm -rf /usr/local/lib/python3.6/dist-packages/tensorflow
#!rm -rf /usr/local/lib/python2.7/dist-packages/tensorflow
#!rm -rf /usr/local/lib/python2.7/dist-packages/keras
#import keras
#print(keras.__version__)
#!cat /usr/local/lib/python3.6/dist-packages/keras/preprocessing/image.py

# %%
#import sys
#sys.path
#!apt-get install cuda-9.0
#import keras
#print(keras.__file__)
#!cat /usr/local/lib/python3.6/dist-packages/keras/__init__.py
#!ls '/usr/local/lib/python3.6/dist-packages/keras/__init__.py'
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())
#import tensorflow as tf
#sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15709612352448796870
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11287966516
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3684788995848155202
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
#!pip install --upgrade --force-reinstall  keras
#!pip uninstall -y tensorflow-gpu
#!pip install --upgrade --force-reinstall  tensorflow-gpu==1.7.0

# %%
#import gc
#gc.collect()
#!ls -lat /content/drive/KerasDeepNet/image.py
#!cat /content/drive/KerasDeepNet/image.py
#
# Out:
# Uninstalling Keras-2.1.6:
#   Successfully uninstalled Keras-2.1.6
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -y
# ls: cannot access '/usr/local/lib/python3.6/dist-packages/keras/preprocessing/': No such file or directory
# rm: cannot remove '/usr/local/lib/python3.6/dist-packages/keras/preprocessing/image.py': No such file or directory
# cp: cannot create regular file '/usr/local/lib/python3.6/dist-packages/keras/preprocessing/image.py': No such file or directory

# %%
# !ls /content/drive/KerasDeepNet/hackerearth
# !mkdir -p /content/archive
#!mkdir -p /content/drive/KerasDeepNet/Animals
#!cp -r /content/drive/KerasDeepNet/hackerearth/*.txt /content/drive/KerasDeepNet/Animals
# !cp -r /content/drive/KerasDeepNet/hackerearth/*.* /content/archive
# Out:
# attributes.txt	classes.txt  meta-data.rar  test_img.rar  train_img.rar

# %%
# !ls /content/archive
# Out:
# attributes.txt	classes.txt  meta-data.rar  test_img.rar  train_img.rar

# %%
# !mkdir -p /content/Animals
# !mkdir -p /content/Animals/data
# !mkdir -p /content/Animals/data/trainval
# !mkdir -p /content/Animals/data/trainval/img
#!mkdir -p /content/Animals/data/train/img
#!mkdir -p /content/Animals/data/validation/img
# !mkdir -p /content/Animals/data/test/
# !mkdir -p /content/Animals/data/test/img
import os
os.chdir('/content/Animals/data/trainval/img')
# !unrar e -o+ -r /content/archive/train_img.rar > /dev/null
os.chdir('/content/Animals/data/test/img')
# !unrar e -o+ -r /content/archive/test_img.rar > /dev/null

# %%
# !ls /content/Animals/data/trainval/img | wc -l
# !ls /content/Animals/data/test/img | wc -l
# !ls /content/Animals/data/trainval/img/*.jpg | wc -l
# !ls /content/Animals/data/test/img/*.jpg | wc -l
#!ls /content
# Out:
# 12600
# 5400
# 12600
# 5400

# %%
os.chdir('/content/Animals/data')
# !unrar e -o+ -r /content/archive/meta-data.rar > /dev/null
# !cp -r /content/archive/*.txt /content/Animals/data

# %%
#!ls /content/Animals/data/
# !ls -lH /content/Animals/data
import os
os.chdir('/content/Animals/data')
# Out:
# total 4012
# -r--r--r-- 1 root root    1205 Jun 11 12:54 attributes.txt
# -r--r--r-- 1 root root     755 Jun 11 12:54 classes.txt
# -rw-r--r-- 1 root root  998754 Apr  4 17:05 sample_submission.csv
# drwxr-xr-x 2 root root  192512 Jun 11 12:53 test
# -rw-r--r-- 1 root root   79904 Apr  5 07:15 test.csv
# -rw-r--r-- 1 root root 2333355 Apr  5 07:19 train.csv
# drwxr-xr-x 2 root root  491520 Jun 11 12:53 trainval

# %% [markdown]
# # **Importing libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_files
from glob import glob
# %matplotlib inline

# %% [markdown]
# # **Data Exploration**

# %%
# Reading the train and test meta-data files
train = pd.read_csv('/content/Animals/data/train.csv',index_col='Image_name')
test = pd.read_csv('/content/Animals/data/test.csv',index_col='Image_name')

# %%
train.head()
# Out:
#              attrib_01  attrib_02  attrib_03  attrib_04  attrib_05  attrib_06  \
# Image_name
# Image-1.jpg          0          0          0          0          0          1
# Image-2.jpg          1          0          0          1          0          0
# Image-3.jpg          1          0          0          1          0          0
# Image-4.jpg          1          0          0          1          0          0
# Image-5.jpg          0          0          0          1          0          0
#
#              attrib_07  attrib_08  attrib_09  attrib_10    ...      attrib_76  \
# Image_name                                                 ...
# Image-1.jpg          1          0          0          0    ...              1
# Image-2.jpg          1          1          0          0    ...              1
# Image-3.jpg          0          1          1          0    ...              1
# Image-4.jpg          0          0          1          1    ...              1
# ...

# %%
test.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Image-1.jpg, Image-2.jpg, Image-3.jpg, Image-4.jpg, Image-5.jpg]

# %%
# Shape of training and test datasets
print ('Training dataset consists of {} images with {} attributes'.format(train.shape[0], train.shape[1]))
# Shape of training and test datasets
print ('Testing dataset consists of {} images.'.format(test.shape[0]))
# Out:
# Training dataset consists of 12600 images with 85 attributes
# Testing dataset consists of 5400 images.

# %%
print('Columns in the dataset:\n\n', train.columns)
# Out:
# Columns in the dataset:
#
#  Index(['attrib_01', 'attrib_02', 'attrib_03', 'attrib_04', 'attrib_05',
#        'attrib_06', 'attrib_07', 'attrib_08', 'attrib_09', 'attrib_10',
#        'attrib_11', 'attrib_12', 'attrib_13', 'attrib_14', 'attrib_15',
#        'attrib_16', 'attrib_17', 'attrib_18', 'attrib_19', 'attrib_20',
#        'attrib_21', 'attrib_22', 'attrib_23', 'attrib_24', 'attrib_25',
#        'attrib_26', 'attrib_27', 'attrib_28', 'attrib_29', 'attrib_30',
#        'attrib_31', 'attrib_32', 'attrib_33', 'attrib_34', 'attrib_35',
#        'attrib_36', 'attrib_37', 'attrib_38', 'attrib_39', 'attrib_40',
#        'attrib_41', 'attrib_42', 'attrib_43', 'attrib_44', 'attrib_45',
#        'attrib_46', 'attrib_47', 'attrib_48', 'attrib_49', 'attrib_50',
#        'attrib_51', 'attrib_52', 'attrib_53', 'attrib_54', 'attrib_55',
#        'attrib_56', 'attrib_57', 'attrib_58', 'attrib_59', 'attrib_60',
#        'attrib_61', 'attrib_62', 'attrib_63', 'attrib_64', 'attrib_65',
# ...

# %% [markdown]
# # **Data Visualization**

# %%
cols = list(train.columns)
print(cols)
cols.remove('Image_name')
cols.sort()
# Out:
# ['Image_name', 'attrib_01', 'attrib_02', 'attrib_03', 'attrib_04', 'attrib_05', 'attrib_06', 'attrib_07', 'attrib_08', 'attrib_09', 'attrib_10', 'attrib_11', 'attrib_12', 'attrib_13', 'attrib_14', 'attrib_15', 'attrib_16', 'attrib_17', 'attrib_18', 'attrib_19', 'attrib_20', 'attrib_21', 'attrib_22', 'attrib_23', 'attrib_24', 'attrib_25', 'attrib_26', 'attrib_27', 'attrib_28', 'attrib_29', 'attrib_30', 'attrib_31', 'attrib_32', 'attrib_33', 'attrib_34', 'attrib_35', 'attrib_36', 'attrib_37', 'attrib_38', 'attrib_39', 'attrib_40', 'attrib_41', 'attrib_42', 'attrib_43', 'attrib_44', 'attrib_45', 'attrib_46', 'attrib_47', 'attrib_48', 'attrib_49', 'attrib_50', 'attrib_51', 'attrib_52', 'attrib_53', 'attrib_54', 'attrib_55', 'attrib_56', 'attrib_57', 'attrib_58', 'attrib_59', 'attrib_60', 'attrib_61', 'attrib_62', 'attrib_63', 'attrib_64', 'attrib_65', 'attrib_66', 'attrib_67', 'attrib_68', 'attrib_69', 'attrib_70', 'attrib_71', 'attrib_72', 'attrib_73', 'attrib_74', 'attrib_75', 'attrib_
# ...

# %%
count_labels = train[cols].sum()
print(count_labels.index)
print(count_labels.values)
# Out:
# Index(['attrib_01', 'attrib_02', 'attrib_03', 'attrib_04', 'attrib_05',
#        'attrib_06', 'attrib_07', 'attrib_08', 'attrib_09', 'attrib_10',
#        'attrib_11', 'attrib_12', 'attrib_13', 'attrib_14', 'attrib_15',
#        'attrib_16', 'attrib_17', 'attrib_18', 'attrib_19', 'attrib_20',
#        'attrib_21', 'attrib_22', 'attrib_23', 'attrib_24', 'attrib_25',
#        'attrib_26', 'attrib_27', 'attrib_28', 'attrib_29', 'attrib_30',
#        'attrib_31', 'attrib_32', 'attrib_33', 'attrib_34', 'attrib_35',
#        'attrib_36', 'attrib_37', 'attrib_38', 'attrib_39', 'attrib_40',
#        'attrib_41', 'attrib_42', 'attrib_43', 'attrib_44', 'attrib_45',
#        'attrib_46', 'attrib_47', 'attrib_48', 'attrib_49', 'attrib_50',
#        'attrib_51', 'attrib_52', 'attrib_53', 'attrib_54', 'attrib_55',
#        'attrib_56', 'attrib_57', 'attrib_58', 'attrib_59', 'attrib_60',
#        'attrib_61', 'attrib_62', 'attrib_63', 'attrib_64', 'attrib_65',
# ...

# %%
count_labels.sort_values(inplace=True)

# %% [markdown]
# From the figure below, we can see that there are 85 different attributes/ labels and Attrib_21 is common in almost all animals while Attrib_66 is rare.

# %%
plt.figure(figsize=(18, 8))
ax = sns.barplot(x=count_labels.index, y=count_labels.values)
ax.set_xticklabels(labels=count_labels.index,rotation=90, ha='right')
ax.set_ylabel('Count')
ax.set_xlabel('Attributes/ Labels')
ax.title.set_text('Label/ Attribute distribution')
plt.tight_layout()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
label_data = np.array(train[cols])

# %% [markdown]
# Next we will compute the co-occurrence matrix for the labels.

# %%
# Compute the cooccurrence matrix
cooccurrence_matrix = np.dot(label_data.transpose(), label_data)
print('\n Co-occurence matrix: \n', cooccurrence_matrix)
# Out:
#  Co-occurence matrix:
#  [[5091  728  797 ... 3797  728 2024]
#  [ 728 1614    0 ...  669 1614 1003]
#  [ 797    0 1188 ... 1188    0  359]
#  ...
#  [3797  669 1188 ... 8305  743 3629]
#  [ 728 1614    0 ...  743 1933 1322]
#  [2024 1003  359 ... 3629 1322 6227]]

# %%
# Compute the cooccurrence matrix in percentage
# Refrence: https://stackoverflow.com/questions/20574257/constructing-a-co-occurrence-matrix-in-python-pandas/20574460
cooccurrence_matrix_diagonal = np.diagonal(cooccurrence_matrix)
with np.errstate(divide = 'ignore', invalid='ignore'):
    cooccurrence_matrix_percentage = np.nan_to_num(np.true_divide(cooccurrence_matrix, cooccurrence_matrix_diagonal))

# %%
print('\n Co-occurrence matrix paercentage: \n', cooccurrence_matrix_percentage)
# Out:
#  Co-occurrence matrix paercentage:
#  [[1.         0.45105328 0.67087542 ... 0.45719446 0.37661666 0.32503613]
#  [0.14299745 1.         0.         ... 0.08055388 0.83497155 0.16107275]
#  [0.15655078 0.         1.         ... 0.14304636 0.         0.05765216]
#  ...
#  [0.74582597 0.41449814 1.         ... 1.         0.38437662 0.58278465]
#  [0.14299745 1.         0.         ... 0.08946418 1.         0.21230127]
#  [0.39756433 0.62143742 0.30218855 ... 0.43696568 0.68391102 1.        ]]

# %% [markdown]
# From the plot of the co-occurence matrix (below), we can see which labels(or attributes) genreally occur together.

# %%
ax = plt.figure(figsize=(18, 12))

sns.set(style='white')

# Generate a custom diverging colormap
cmap = sns.diverging_palette(200, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio 
sns.heatmap(cooccurrence_matrix_percentage, cmap=cmap, center=0, square=True, linewidths=0.15, cbar_kws={"shrink": 0.5})

plt.title('Co-occurrence Matrix of the Labels')
# Out:
# Text(0.5,1,'Co-occurrence Matrix of the Labels')

# %% [markdown]
# We define the paths to the image folders.

# %%
TRAIN_PATH = '/content/Animals/data/trainval/'
TEST_PATH = '/content/Animals/data/test/'

# %%
img_path = TRAIN_PATH+str(train.Image_name[0])
print(img_path)
# Out:
# /content/Animals/data/trainval/Image-1.jpg

# %% [markdown]
# We import the OpenCV and Python Image library for image manipulation.

# %%
from PIL import Image
import cv2

# %%
Image.open(img_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F14B5412DA0>

# %%
img = cv2.imread(img_path)
img
# Out:
# array([[[ 54,  56,  64],
#         [ 58,  60,  70],
#         [ 59,  64,  73],
#         ...,
#         [ 70,  65,  62],
#         [ 70,  66,  65],
#         [ 70,  66,  65]],
#
#        [[ 56,  59,  67],
#         [ 59,  61,  71],
#         [ 60,  65,  74],
#         ...,
#         [ 71,  66,  65],
#         [ 71,  68,  64],
#         [ 71,  68,  64]],
#
#        [[ 59,  62,  70],
#         [ 62,  64,  74],
#         [ 63,  68,  77],
#         ...,
#         [ 73,  65,  66],
#         [ 71,  66,  63],
#         [ 70,  67,  62]],
#
#        ...,
#
#        [[192, 216, 238],
#         [190, 214, 236],
#         [191, 214, 236],
#         ...,
#         [ 51,  48,  44],
#         [ 47,  42,  39],
#         [ 40,  35,  32]],
#
#        [[186, 213, 234],
#         [188, 212, 234],
#         [187, 211, 233],
#         ...,
#         [ 55,  52,  48],
#         [ 48,  45,  41],
#         [ 41,  36,  33]],
#
#        [[178, 205, 226],
#         [183, 210, 231],
#         [184, 208, 230],
# ...

# %%
# Shape of each image
img.shape
# Out:
# (768, 1024, 3)

# %%
# Extracting label columns
label_cols = list(set(train.columns) - set(['Image_name']))
label_cols.sort()

# %%
# Extracting labels corresponding to image at the zeroth index of the training dataset.
labels = train.iloc[0][2:].index[train.iloc[0][2:] == 1]

# %% [markdown]
# We plot the Animal and the attributes/ labels corresponding to it.

# %%
txt = 'Labels/ Attributes: ' + str(labels.values)
ax = plt.figure(figsize=(10, 10))
ax.text(.5, .05, txt, ha='center')
plt.imshow(img)

# %%
#!sed -i 's/\x0//g' /usr/local/lib/python3.6/dist-packages/keras/engine/training.py
#!sed  -i 's/\x0/ /g' /usr/local/lib/python3.6/dist-packages/keras/engine/training.py
#!sed  -i 's/\x0/ /g' /usr/local/lib/python3.6/dist-packages/keras/preprocessing/image.py
import compileall
compileall.compile_dir('/usr/local/lib/python3.6/dist-packages/keras/engine', force=True)
compileall.compile_dir('/usr/local/lib/python3.6/dist-packages/keras/preprocessing', force=True)
# Out:
# Listing '/usr/local/lib/python3.6/dist-packages/keras/engine'...
# Compiling '/usr/local/lib/python3.6/dist-packages/keras/engine/__init__.py'...
# Compiling '/usr/local/lib/python3.6/dist-packages/keras/engine/topology.py'...
# Compiling '/usr/local/lib/python3.6/dist-packages/keras/engine/training.py'...
# Listing '/usr/local/lib/python3.6/dist-packages/keras/preprocessing'...
# Compiling '/usr/local/lib/python3.6/dist-packages/keras/preprocessing/__init__.py'...
# Compiling '/usr/local/lib/python3.6/dist-packages/keras/preprocessing/image.py'...
# Compiling '/usr/local/lib/python3.6/dist-packages/keras/preprocessing/sequence.py'...
# Compiling '/usr/local/lib/python3.6/dist-packages/keras/preprocessing/text.py'...
# True

# %%
#!pip install h5py_cache
#!cp -r /content/Animals/all_image_features_224.h5 /content/drive/KerasDeepNet/Animals
#!cp -r /content/Animals/all_image_labels_224.h5 /content/drive/KerasDeepNet/Animals
#!cp -r /content/Animals/all_image_features_299.h5 /content/drive/KerasDeepNet/Animals
#!cp -r /content/Animals/all_image_labels_299.h5 /content/drive/KerasDeepNet/Animals
#!cp -r /content/Animals/all_image_features_329.h5 /content/drive/KerasDeepNet/Animals
#!cp -r /content/Animals/all_image_labels_329.h5 /content/drive/KerasDeepNet/Animals
#!cp -r /content/Animals/data/train.csv /content/drive/KerasDeepNet/Animals
#!cp -r /content/Animals/data/test.csv /content/drive/KerasDeepNet/Animals

# %%
# !ls -lht /content/drive/KerasDeepNet/Animals/
# !cp -r /content/Animals/all_bottleneck_resnet_features_224.h5 /content/drive/KerasDeepNet/Animals/all_bottleneck_resnet_features_224.h5
# !cp -r /content/Animals/all_bottleneck_resnet_labels_224.h5 /content/drive/KerasDeepNet/Animals/all_bottleneck_resnet_labels_224.h5
# !cp -r /content/Animals/bottleneck_resnet_weights.h5 /content/drive/KerasDeepNet/Animals/bottleneck_resnet_weights.h5
# Out:
# total 9.6G
# -rw-r--r-- 1 root root  17M Jun 15 11:17 bottleneck_vgg16_weights.h5
# -rw-r--r-- 1 root root 4.1M Jun 15 11:17 all_bottleneck_vgg16_labels_224.h5
# -rw-r--r-- 1 root root  80M Jun 15 11:16 all_bottleneck_vgg16_features_224.h5
# -rw-r--r-- 1 root root 4.1M Jun 14 18:31 all_bottleneck_resnet_labels_224.h5
# -rw-r--r-- 1 root root 2.1M Jun 14 18:29 bottleneck_resnet_weights.h5
# -rw-r--r-- 1 root root  94M Jun 14 18:26 all_bottleneck_resnet_features_224.h5
# -rw-r--r-- 1 root root 4.1M Jun 14 14:57 all_image_labels_299.h5
# -rw-r--r-- 1 root root 6.0G Jun 14 14:57 all_image_features_299.h5
# -rw-r--r-- 1 root root 4.1M Jun 14 14:35 all_image_labels_224.h5
# -rw-r--r-- 1 root root 3.5G Jun 14 14:35 all_image_features_224.h5
# -rw-r--r-- 1 root root  79K Jun 14 14:20 test.csv
# -rw-r--r-- 1 root root 2.3M Jun 14 14:20 train.csv
# -r--r--r-- 1 root root 1.2K Jun 10 20:21 attributes.txt
# -r--r--r-- 1 root root  755 Jun 10 20:21 classes.txt

# %% [markdown]
# # **Save Image Features Before any preprocessing after resizing**

# %%
#del K
#import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential,Model
from keras.layers import Input,Dropout, Flatten, Dense
from keras import applications
from keras.applications.resnet50 import ResNet50, preprocess_input
import keras
import h5py_cache as h5c
import h5py as h5
import random
from sklearn.utils import shuffle
from math import *
import threading
print("Keras Imported")
full_data_dir = '/content/Animals/data/trainval/'
batch_size = 64
def calculateDividingFactor(shape):
    total_mem_usage = min(np.prod(shape)*4,1024**2*15000)
    total_mem_gb = total_mem_usage/(1024**3)
    dividing_factor  = 1
    if(0.5 <total_mem_gb < 2):
        dividing_factor = 3
    elif(2< total_mem_gb < 6):
        dividing_factor = 4
    elif( 6 <total_mem_gb < 10):
        dividing_factor = 5
    elif(total_mem_gb >10):
        dividing_factor = 6
    return total_mem_usage,dividing_factor
def save_image_features(img_width, img_height,all_features_hdf5,all_labels_hdf5,train):
    datagen = ImageDataGenerator()
    #Build a fake model
    model = Sequential()
    generator = datagen.flow_from_directory(
        full_data_dir,
        target_size=(img_height,img_width),
        batch_size=batch_size,
        interpolation='lanczos',
        class_mode=None,
        table_pd =train)
   
    shape = (generator.samples, img_width,img_height,3 )
    chunk_shape=(1, 100,100,3)
    total_mem_usage,dividing_factor = calculateDividingFactor(shape)
    f1_all = h5c.File(all_features_hdf5, 'w',chunk_cache_mem_size=total_mem_usage//dividing_factor)
    f1_label = h5.File(all_labels_hdf5, 'w')
    d1_all = f1_all.create_dataset('data', shape ,dtype='float32',chunks=chunk_shape,compression="lzf")
    d1_label = f1_label.create_dataset('data', (generator.samples,len(generator.table_pd.columns)) ,dtype='float32')
    model.write_generator(generator, 
                          steps = int(ceil(generator.samples/ batch_size)),
                           max_queue_size=10,
                           workers=4,
                           use_multiprocessing=False,
                           verbose=0,
                           d_set= d1_all,
                           label_set =d1_label)
    f1_all.close()
    f1_label.close()
img_width, img_height = 224, 224
all_features_hdf5 = '/content/Animals/all_image_features_224.h5'
all_labels_hdf5 = '/content/Animals/all_image_labels_224.h5'
save_image_features(img_width, img_height,all_features_hdf5,all_labels_hdf5,train)
#img_width, img_height = 299, 299
#all_features_hdf5 = '/content/Animals/all_image_features_299.h5'
#all_labels_hdf5 = '/content/Animals/all_image_labels_299.h5'
#save_image_features(img_width, img_height,all_features_hdf5,all_labels_hdf5,train)
#img_width, img_height = 329, 329
#all_features_hdf5 = '/content/Animals/all_image_features_329.h5'
#all_labels_hdf5 = '/content/Animals/all_image_labels_329.h5'
#save_image_features(img_width, img_height,all_features_hdf5,all_labels_hdf5,train)
# Out:
# Keras Imported
# Found 12600 images belonging to 1 classes.

# %% [markdown]
# # **ResNet Model with Extracted Features**

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential,Model
from keras.layers import Input,Dropout, Flatten, Dense
from keras import applications
from keras.applications.resnet50 import ResNet50, preprocess_input
import keras
from keras import backend as K
import h5py_cache as h5c
import h5py as h5
import random
from sklearn.utils import shuffle
from math import *
import threading
print("Keras Imported")
full_data_dir = '/content/Animals/data/trainval/'
batch_size = 64
img_width, img_height = 224, 224
all_features_hdf5 = '/content/Animals/all_bottleneck_resnet_features_224.h5'
all_labels_hdf5 = '/content/Animals/all_bottleneck_resnet_labels_224.h5'
top_model_weights_path = '/content/Animals/bottleneck_resnet_weights.h5'
#Resnet models should be trained to 30 epochs. Is very hard to tune the parameters end to end.
epochs = 20
def calculateDividingFactor(shape):
    total_mem_usage = min(np.prod(shape)*4,1024**2*15000)
    total_mem_gb = total_mem_usage/(1024**3)
    dividing_factor  = 1
    if(0.5 <total_mem_gb < 2):
        dividing_factor = 3
    elif(2< total_mem_gb < 6):
        dividing_factor = 4
    elif( 6 <total_mem_gb < 10):
        dividing_factor = 5
    elif(total_mem_gb >10):
        dividing_factor = 6
    return total_mem_usage,dividing_factor
def save_bottleneck_features(all_features_hdf5,all_labels_hdf5):
    # rescale= 1./255 doest work for Vgg. preprocess_input works
    #datagen = ImageDataGenerator(rescale=1. / 255)
    datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
    input_s = Input(shape=(img_width,img_height,3))
    # build the ResNet50 network
    base_model = ResNet50(include_top=False, weights='imagenet',input_tensor=input_s)
    model = Model(inputs=base_model.input, outputs=base_model.output)
    generator = datagen.flow_from_directory(
        full_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        interpolation='lanczos',
        class_mode=None,
        table_pd =train)
    model.write_predict_generator(generator, 
                          steps=generator.samples//batch_size,
                           max_queue_size=10,
                           workers=4,
                           use_multiprocessing=False,
                           verbose=0,
                           h5py_file = all_features_hdf5,
                           h5py_label =all_labels_hdf5)
 

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))



def train_new_top_model(all_features_hdf5,all_labels_hdf5):
    #The Bottleneck or other image extracted features are  stored in h5 files
    # Use HDF5MatrixCacheIterator to use them. By default HDF5MatrixCacheIterator doesnt transform and doesnt shuffle.
    # so we can use old ImageDataGenerator

    datagen = ImageDataGenerator(validation_split=0.2)
    f1_trainvalidation = h5.File(all_features_hdf5, 'r')
    shape = f1_trainvalidation['data'].shape
    f1_trainvalidation.close()
    #15 Gb is upper limit for cache memory.
    total_mem_usage,dividing_factor = calculateDividingFactor(shape)
    
    #print("Dividing factor {}:".format(dividing_factor))
    print("Cached memory usage: {}".format(total_mem_usage /(1024**3)/dividing_factor))
    chunk_shape = (1, max(shape[1]//2,1), max(shape[2]//2,1),max(shape[3]//2,1))
    f1_trainvalidation = h5c.File(all_features_hdf5, 'r',chunk_cache_mem_size=total_mem_usage//dividing_factor)
    f1_label = h5.File(all_labels_hdf5, 'r')
    train_generator = datagen.flow_hdf5(
        f1_trainvalidation['data'],
        f1_label['data'],
        subset = 'training',
        batch_size=batch_size,
        shuffle=False)
    validation_generator = datagen.flow_hdf5(
        f1_trainvalidation['data'],
        f1_label['data'],
        subset = 'validation',
        batch_size=batch_size,
        shuffle=False)
    model = Sequential()
    model.add(Flatten(input_shape=shape[1:]))
    model.add(Dense(1024, activation='relu'))
    #model.add(Dense(256,input_shape=(train_data_shape[1:],),activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(85, activation='sigmoid'))

    #model.compile(optimizer='rmsprop',loss='binary_crossentropy', metrics=['accuracy'])
    model.compile(loss='binary_crossentropy',optimizer= "adam", metrics=[f1])
    model.fit_generator(generator = train_generator,
                        steps_per_epoch = int(ceil(train_generator.samples/ batch_size)),
                        validation_data = validation_generator, 
                        max_queue_size=10,  # use a value which can fit batch_size * image_size * max_queue_size in your CPU memory
                        workers=4,  # I don't see multi workers can have any performance benefit without multi threading
                        use_multiprocessing=False,  # HDF5Matrix cannot support multi-threads
                        validation_steps = int(ceil(validation_generator.samples/ batch_size)),
                        shuffle=True,
                        epochs = epochs)
    model.save_weights(top_model_weights_path)
#save_bottleneck_features(all_features_hdf5, all_labels_hdf5)
train_new_top_model(all_features_hdf5, all_labels_hdf5)
# Out:
# Keras Imported
# Cached memory usage: 0.09613037109375
# Epoch 1/20
# 158/158 [==============================] - 4s 25ms/step - loss: 0.2260 - f1: 0.8631 - val_loss: 0.1043 - val_f1: 0.9451
# Epoch 2/20
# 158/158 [==============================] - 3s 16ms/step - loss: 0.1075 - f1: 0.9380 - val_loss: 0.0719 - val_f1: 0.9632
# Epoch 3/20
# 158/158 [==============================] - 3s 16ms/step - loss: 0.0775 - f1: 0.9552 - val_loss: 0.0622 - val_f1: 0.9678
# Epoch 4/20
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0607 - f1: 0.9644 - val_loss: 0.0561 - val_f1: 0.9705
# Epoch 5/20
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0493 - f1: 0.9705 - val_loss: 0.0512 - val_f1: 0.9739
# Epoch 6/20
# ...
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0424 - f1: 0.9740 - val_loss: 0.0515 - val_f1: 0.9741
# Epoch 7/20
# ...

# %% [markdown]
# # **ResNet50 with loaded  bottleneck Weights and Directory Images(slow)**

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential,Model
from keras.layers import Input,Dropout, Flatten, Dense
from keras import applications,optimizers
from keras.applications.resnet50 import ResNet50, preprocess_input
import keras
from keras import backend as K
import h5py_cache as h5c
import h5py as h5
import random
from sklearn.utils import shuffle
from math import *
import threading
print("Keras Imported")
full_data_dir = '/content/Animals/data/trainval/'
batch_size = 64
img_width, img_height = 224, 224
top_model_weights_path = '/content/Animals/bottleneck_resnet_weights.h5'
epochs = 30

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

 
input_s = Input(shape=(img_height,img_width,3))
# build the ResNet50 network
base_model = ResNet50(include_top=False, weights='imagenet',input_tensor=input_s)

# build a classifier model to put on top of the convolutional model
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(256, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(85, activation='sigmoid'))

# note that it is necessary to start with a fully-trained
# classifier, including the top classifier,
# in order to successfully do fine-tuning
top_model.load_weights(top_model_weights_path)

# add the model on top of the convolutional base

model = Model(inputs= base_model.input, outputs= top_model(base_model.output))

# set the first 25 layers (up to the last conv block)
# to non-trainable (weights will not be updated)
for layer in model.layers[:25]:
    layer.trainable = False

# compile the model with a SGD/momentum optimizer
# and a very slow learning rate.
#model.compile(loss='binary_crossentropy',optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),metrics=['accuracy'])
model.compile(loss='binary_crossentropy',optimizer=optimizers.SGD(lr=1e-4, momentum=0.9), metrics=[f1])
# prepare data augmentation configuration
datagen = ImageDataGenerator(preprocessing_function = preprocess_input,
                            validation_split=0.2)


train_generator = datagen.flow_from_directory(
        full_data_dir,
        target_size=(img_height,img_width),
        batch_size=batch_size,
        interpolation='lanczos',
        subset = 'training',
        class_mode=None,
        table_pd =train)

validation_generator = datagen.flow_from_directory(
        full_data_dir,
        target_size=(img_height,img_width),
        batch_size=batch_size,
        interpolation='lanczos',
        subset = 'validation',
        class_mode=None,
        table_pd =train)

# fine-tune the model
model.fit_generator(generator = train_generator,
                        steps_per_epoch = int(ceil(train_generator.samples/ batch_size)),
                        validation_data = validation_generator, 
                        max_queue_size=10,  # use a value which can fit batch_size * image_size * max_queue_size in your CPU memory
                        workers=4,  
                        use_multiprocessing=False, 
                        validation_steps = int(ceil(validation_generator.samples/ batch_size)),
                        shuffle=True,
                        epochs = epochs)
# Out:
# Keras Imported
# Found 10080 images belonging to 1 classes.
# Found 2520 images belonging to 1 classes.
# Epoch 1/30
# 158/158 [==============================] - 376s 2s/step - loss: 0.1115 - acc: 0.9583 - val_loss: 0.0471 - val_acc: 0.9841
# Epoch 2/30
# 158/158 [==============================] - 352s 2s/step - loss: 0.0990 - acc: 0.9620 - val_loss: 0.0440 - val_acc: 0.9852
# Epoch 3/30
# ...
#  84/158 [==============>...............] - ETA: 2:06 - loss: 0.0898 - acc: 0.9655

# %% [markdown]
# # **ResNet50 with loaded bottleneck Weights and  Raw H5py  Matrix **

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential,Model
from keras.layers import Input,Dropout, Flatten, Dense
from keras import applications,optimizers
from keras.applications.resnet50 import ResNet50, preprocess_input
import keras
from keras import backend as K
import h5py_cache as h5c
import h5py as h5
import random
from sklearn.utils import shuffle
from math import *
import threading
batch_size = 64
img_width, img_height = 224, 224
all_features_hdf5 = '/content/Animals/all_image_features_224.h5'
all_labels_hdf5 = '/content/Animals/all_image_labels_224.h5'
top_model_weights_path = '/content/Animals/bottleneck_resnet_weights.h5'
epochs = 30
def calculateDividingFactor(shape):
    total_mem_usage = min(np.prod(shape)*4,1024**2*15000)
    total_mem_gb = total_mem_usage/(1024**3)
    dividing_factor  = 1
    if(0.5 <total_mem_gb < 2):
        dividing_factor = 2
    elif(2< total_mem_gb < 6):
        dividing_factor = 3
    elif( 6 <total_mem_gb < 10):
        dividing_factor = 4
    elif(total_mem_gb >10):
        dividing_factor = 5
    return total_mem_usage,dividing_factor
  
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

 
input_s = Input(shape=(img_height,img_width,3))
# build the ResNet50 network
base_model = ResNet50(include_top=False, weights='imagenet',input_tensor=input_s)

# build a classifier model to put on top of the convolutional model
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(1024, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(85, activation='sigmoid'))

# note that it is necessary to start with a fully-trained
# classifier, including the top classifier,
# in order to successfully do fine-tuning
top_model.load_weights(top_model_weights_path)

# add the model on top of the convolutional base

model = Model(inputs= base_model.input, outputs= top_model(base_model.output))

# set the first 25 layers (up to the last conv block)
# to non-trainable (weights will not be updated)
for layer in model.layers[:6]:
    layer.trainable = False

# compile the model with a SGD/momentum optimizer
# and a very slow learning rate.
#model.compile(loss='binary_crossentropy',optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),metrics=['accuracy'])
model.compile(loss='binary_crossentropy',optimizer=optimizers.SGD(lr=1e-4, momentum=0.9), metrics=[f1])
# prepare data augmentation configuration

# Raw Features need to be transformed and standardized
datagen = ImageDataGenerator(preprocessing_function = preprocess_input,
                            validation_split=0.2,
                            apply_gen_transform= True)

f1_trainvalidation = h5.File(all_features_hdf5, 'r')
shape = f1_trainvalidation['data'].shape
f1_trainvalidation.close()
#15 Gb is upper limit for cache memory.
total_mem_usage,dividing_factor = calculateDividingFactor(shape)

#print("Dividing factor {}:".format(dividing_factor))
print("Cached memory usage: {}".format(total_mem_usage /(1024**3)/dividing_factor))
chunk_shape = (1, 100, 100, 3)
f1_trainvalidation = h5c.File(all_features_hdf5, 'r',chunk_cache_mem_size=total_mem_usage//dividing_factor)
f1_label = h5.File(all_labels_hdf5, 'r')
train_generator = datagen.flow_hdf5(
    f1_trainvalidation['data'],
    f1_label['data'],
    subset = 'training',
    batch_size=batch_size,
    shuffle=False)
validation_generator = datagen.flow_hdf5(
    f1_trainvalidation['data'],
    f1_label['data'],
    subset = 'validation',
    batch_size=batch_size,
    shuffle=False)
    
# fine-tune the model
model.fit_generator(generator = train_generator,
                        steps_per_epoch = int(ceil(train_generator.samples/ batch_size)),
                        validation_data = validation_generator, 
                        max_queue_size=10,  # use a value which can fit batch_size * image_size * max_queue_size in your CPU memory
                        workers=4,  
                        use_multiprocessing=False, 
                        validation_steps = int(ceil(validation_generator.samples/ batch_size)),
                        shuffle=True,
                        epochs = epochs)
# Out:
# Using TensorFlow backend.
# Cached memory usage: 1.7663955688476562
# Epoch 1/30
# 158/158 [==============================] - 294s 2s/step - loss: 0.0676 - f1: 0.9684 - val_loss: 0.0292 - val_f1: 0.9871
# Epoch 2/30
# 158/158 [==============================] - 276s 2s/step - loss: 0.0548 - f1: 0.9741 - val_loss: 0.0255 - val_f1: 0.9890
# Epoch 3/30
# ...
# 158/158 [==============================] - 276s 2s/step - loss: 0.0475 - f1: 0.9775 - val_loss: 0.0234 - val_f1: 0.9900
# Epoch 4/30
# 158/158 [==============================] - 276s 2s/step - loss: 0.0429 - f1: 0.9797 - val_loss: 0.0219 - val_f1: 0.9907
# Epoch 5/30
# 158/158 [==============================] - 276s 2s/step - loss: 0.0381 - f1: 0.9822 - val_loss: 0.0212 - val_f1: 0.9910
# Epoch 6/30
# ...
# 158/158 [==============================] - 276s 2s/step - loss: 0.0352 - f1: 0.9834 - val_loss: 0.0202 - val_f1: 0.9916
# Epoch 7/30
# ...

# %% [markdown]
# # **Vgg 16 Model with Extracted Features**

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential,Model
from keras.layers import Input,Dropout, Flatten, Dense
from keras import applications
from keras.applications.vgg16 import VGG16, preprocess_input
import keras
from keras import backend as K
import h5py_cache as h5c
import h5py as h5
import random
from sklearn.utils import shuffle
from math import *
import threading
print("Keras Imported")
full_data_dir = '/content/Animals/data/trainval/'
batch_size = 64
img_width, img_height = 224, 224
all_features_hdf5 = '/content/Animals/all_bottleneck_vgg16_features_224.h5'
all_labels_hdf5 = '/content/Animals/all_bottleneck_vgg16_labels_224.h5'
top_model_weights_path = '/content/Animals/bottleneck_vgg16_weights.h5'
epochs = 30
def calculateDividingFactor(shape):
    total_mem_usage = min(np.prod(shape)*4,1024**2*15000)
    total_mem_gb = total_mem_usage/(1024**3)
    dividing_factor  = 1
    if(0.5 <total_mem_gb < 2):
        dividing_factor = 3
    elif(2< total_mem_gb < 6):
        dividing_factor = 4
    elif( 6 <total_mem_gb < 10):
        dividing_factor = 5
    elif(total_mem_gb >10):
        dividing_factor = 6
    return total_mem_usage,dividing_factor
def save_bottleneck_features(all_features_hdf5,all_labels_hdf5):
    # rescale= 1./255 doest work for Vgg. preprocess_input works
    #datagen = ImageDataGenerator(rescale=1. / 255)
    datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
    input_s = Input(shape=(img_width,img_height,3))
    # build the VGG16 network
    base_model = VGG16(include_top=True, weights='imagenet',input_tensor=input_s)
    model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)
    generator = datagen.flow_from_directory(
        full_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        interpolation='lanczos',
        class_mode=None,
        table_pd =train)
    model.write_predict_generator(generator, 
                          steps=generator.samples//batch_size,
                           max_queue_size=10,
                           workers=4,
                           use_multiprocessing=False,
                           verbose=0,
                           h5py_file = all_features_hdf5,
                           h5py_label =all_labels_hdf5)
 

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))



def train_new_top_model(all_features_hdf5,all_labels_hdf5):
    #The Bottleneck or other image extracted features are  stored in h5 files
    # Use HDF5MatrixCacheIterator to use them. By default HDF5MatrixCacheIterator doesnt transform and doesnt shuffle.
    # so we can use old ImageDataGenerator

    datagen = ImageDataGenerator(validation_split=0.2)
    f1_trainvalidation = h5.File(all_features_hdf5, 'r')
    shape = f1_trainvalidation['data'].shape
    f1_trainvalidation.close()
    #15 Gb is upper limit for cache memory.
    total_mem_usage,dividing_factor = calculateDividingFactor(shape)
    
    #print("Dividing factor {}:".format(dividing_factor))
    print("Cached memory usage: {}".format(total_mem_usage /(1024**3)/dividing_factor))
    len_tuple = len(shape)
    chunk_shape = (1,)
    for chunk_index in range(1,len_tuple):
      chunk_shape+=(max(1,shape[chunk_index]//2),)
    f1_trainvalidation = h5c.File(all_features_hdf5, 'r',chunk_cache_mem_size=total_mem_usage//dividing_factor)
    f1_label = h5.File(all_labels_hdf5, 'r')
    train_generator = datagen.flow_hdf5(
        f1_trainvalidation['data'],
        f1_label['data'],
        subset = 'training',
        batch_size=batch_size,
        shuffle=False)
    validation_generator = datagen.flow_hdf5(
        f1_trainvalidation['data'],
        f1_label['data'],
        subset = 'validation',
        batch_size=batch_size,
        shuffle=False)
    model = Sequential()
    model.add(Dense(1024,input_shape=(shape[1:]),activation='relu'))
    #model.add(Dense(1024,input_shape=(shape[1],),activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(85, activation='sigmoid'))

    #model.compile(optimizer='rmsprop',loss='binary_crossentropy', metrics=['accuracy'])
    model.compile(loss='binary_crossentropy',optimizer= "adam", metrics=[f1])
    model.fit_generator(generator = train_generator,
                        steps_per_epoch = int(ceil(train_generator.samples/ batch_size)),
                        validation_data = validation_generator, 
                        max_queue_size=10,  # use a value which can fit batch_size * image_size * max_queue_size in your CPU memory
                        workers=4,  # I don't see multi workers can have any performance benefit without multi threading
                        use_multiprocessing=False,  # HDF5Matrix cannot support multi-threads
                        validation_steps = int(ceil(validation_generator.samples/ batch_size)),
                        shuffle=True,
                        epochs = epochs)
    model.save_weights(top_model_weights_path)
#save_bottleneck_features(all_features_hdf5, all_labels_hdf5)
train_new_top_model(all_features_hdf5, all_labels_hdf5)
# Out:
# Keras Imported
# Cached memory usage: 0.1922607421875
# Epoch 1/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.3426 - f1: 0.8341 - val_loss: 0.1065 - val_f1: 0.9403
# Epoch 2/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1255 - f1: 0.9264 - val_loss: 0.0829 - val_f1: 0.9548
# Epoch 3/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0882 - f1: 0.9477 - val_loss: 0.0718 - val_f1: 0.9617
# Epoch 4/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0675 - f1: 0.9597 - val_loss: 0.0706 - val_f1: 0.9630
# Epoch 5/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0567 - f1: 0.9651 - val_loss: 0.0692 - val_f1: 0.9649
# Epoch 6/30
# ...
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0486 - f1: 0.9696 - val_loss: 0.0653 - val_f1: 0.9669
# Epoch 7/30
# ...

# %%
# !cp /content/Animals/all_bottleneck_vgg16_features_224.h5 /content/drive/KerasDeepNet/Animals/all_bottleneck_vgg16_features_224.h5
# !cp /content/Animals/all_bottleneck_vgg16_labels_224.h5 /content/drive/KerasDeepNet/Animals/all_bottleneck_vgg16_labels_224.h5
# !cp /content/Animals/bottleneck_vgg16_weights.h5 /content/drive/KerasDeepNet/Animals/bottleneck_vgg16_weights.h5

# %% [markdown]
# # **VGG16 with loaded bottleneck Weights and Raw H5py Matrix**

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential,Model
from keras.layers import Input,Dropout, Flatten, Dense
from keras import applications,optimizers
from keras.applications.vgg16 import VGG16, preprocess_input
import keras
from keras import backend as K
import h5py_cache as h5c
import h5py as h5
import random
from sklearn.utils import shuffle
from math import *
import threading
batch_size = 64
img_width, img_height = 224, 224
#all_image_features_224.h5
#all_image_labels_224.h5
all_features_hdf5 = '/content/Animals/all_image_features_224.h5'
all_labels_hdf5 = '/content/Animals/all_image_labels_224.h5'
top_model_weights_path = '/content/Animals/bottleneck_vgg16_weights.h5'
epochs = 30
def calculateDividingFactor(shape):
    total_mem_usage = min(np.prod(shape)*4,1024**2*15000)
    total_mem_gb = total_mem_usage/(1024**3)
    dividing_factor  = 1
    if(0.5 <total_mem_gb < 2):
        dividing_factor = 2
    elif(2< total_mem_gb < 6):
        dividing_factor = 3
    elif( 6 <total_mem_gb < 10):
        dividing_factor = 4
    elif(total_mem_gb >10):
        dividing_factor = 5
    return total_mem_usage,dividing_factor
  
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

 
input_s = Input(shape=(img_height,img_width,3))
# build the VGG16 network
base_model = VGG16(include_top=True, weights='imagenet',input_tensor=input_s)
# build a classifier model to put on top of the convolutional model
top_model = Sequential()
top_model.add(Dense(1024, input_shape=(base_model.get_layer('fc1').output_shape[1:]),activation='relu'))
#top_model.add(Dense(1024, input_shape=(base_model.get_layer('fc1').output_shape[1],),activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(85, activation='sigmoid'))

# note that it is necessary to start with a fully-trained
# classifier, including the top classifier,
# in order to successfully do fine-tuning
top_model.load_weights(top_model_weights_path)

# add the model on top of the convolutional base

model = Model(inputs= base_model.input, outputs= top_model(base_model.get_layer('fc1').output))

# set the first 7 layers (up to the last conv block)
# to non-trainable (weights will not be updated)
for layer in model.layers[:7]:
    layer.trainable = False

# compile the model with a SGD/momentum optimizer
# and a very slow learning rate.
#model.compile(loss='binary_crossentropy',optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),metrics=['accuracy'])
model.compile(loss='binary_crossentropy',optimizer=optimizers.SGD(lr=1e-4, momentum=0.9), metrics=[f1])
# prepare data augmentation configuration

# Raw Features need to be transformed and standardized
datagen = ImageDataGenerator(preprocessing_function = preprocess_input,
                            validation_split=0.2,
                            apply_gen_transform= True)

f1_trainvalidation = h5.File(all_features_hdf5, 'r')
shape = f1_trainvalidation['data'].shape
f1_trainvalidation.close()
#15 Gb is upper limit for cache memory.
total_mem_usage,dividing_factor = calculateDividingFactor(shape)

#print("Dividing factor {}:".format(dividing_factor))
print("Cached memory usage: {}".format(total_mem_usage /(1024**3)/dividing_factor))
chunk_shape = (1, 100, 100, 3)
f1_trainvalidation = h5c.File(all_features_hdf5, 'r',chunk_cache_mem_size=total_mem_usage//dividing_factor)
f1_label = h5.File(all_labels_hdf5, 'r')
train_generator = datagen.flow_hdf5(
    f1_trainvalidation['data'],
    f1_label['data'],
    subset = 'training',
    batch_size=batch_size,
    shuffle=False)
validation_generator = datagen.flow_hdf5(
    f1_trainvalidation['data'],
    f1_label['data'],
    subset = 'validation',
    batch_size=batch_size,
    shuffle=False)
    
# fine-tune the model
model.fit_generator(generator = train_generator,
                        steps_per_epoch = int(ceil(train_generator.samples/ batch_size)),
                        validation_data = validation_generator, 
                        max_queue_size=10,  # use a value which can fit batch_size * image_size * max_queue_size in your CPU memory
                        workers=4,  
                        use_multiprocessing=False, 
                        validation_steps = int(ceil(validation_generator.samples/ batch_size)),
                        shuffle=False,
                        epochs = epochs)
# Out:
# Cached memory usage: 1.7663955688476562
# Epoch 1/30
# 158/158 [==============================] - 249s 2s/step - loss: 0.0402 - f1: 0.9832 - val_loss: 0.0185 - val_f1: 0.9923
# Epoch 2/30
# 158/158 [==============================] - 230s 1s/step - loss: 0.0301 - f1: 0.9850 - val_loss: 0.0177 - val_f1: 0.9923
# Epoch 3/30
# ...
# 158/158 [==============================] - 229s 1s/step - loss: 0.0268 - f1: 0.9866 - val_loss: 0.0179 - val_f1: 0.9922
# Epoch 4/30
# 158/158 [==============================] - 228s 1s/step - loss: 0.0234 - f1: 0.9875 - val_loss: 0.0176 - val_f1: 0.9925
# Epoch 5/30
# 158/158 [==============================] - 229s 1s/step - loss: 0.0232 - f1: 0.9878 - val_loss: 0.0175 - val_f1: 0.9926
# Epoch 6/30
# ...
#  29/158 [====>.........................] - ETA: 2:42 - loss: 0.0201 - f1: 0.9879
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %% [markdown]
# # **Prototype Keras Model with Pandas Support in Flow Full pipeline**

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,BatchNormalization
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K


# dimensions of our images.
img_width, img_height = 224, 224

data_dir = '/content/Animals/data/trainval'
epochs = 50
batch_size = 64

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

model = Sequential()
model.add(BatchNormalization(input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation= 'relu'))

model.add(Conv2D(64, kernel_size=(3, 3), activation= 'relu', padding='same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation= 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), activation= 'relu', padding='same'))
model.add(Conv2D(128, kernel_size=(3, 3), activation= 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(85, activation='sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
early_stops = EarlyStopping(patience=3, monitor='val_acc')
checkpointer = ModelCheckpoint(filepath='weights.best.eda.hdf5', verbose=1, save_best_only=True)

# this is the augmentation configuration we will use for training
datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2)



train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode=None,
    subset = 'training',
    table_pd =train)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode=None,
    subset = 'validation',
    table_pd =train)

model.fit_generator(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    max_queue_size=20,
    workers=4,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size)

#model.save_weights('/content/drive/KerasDeepNet/CatsDogs/first_try.h5')
# Out:
# Found 10080 images belonging to 1 classes.
# Found 2520 images belonging to 1 classes.
# Epoch 1/50
# 157/157 [==============================] - 323s 2s/step - loss: 0.5177 - acc: 0.7556 - val_loss: 0.4503 - val_acc: 0.7795
# Epoch 2/50
# 157/157 [==============================] - 318s 2s/step - loss: 0.4492 - acc: 0.7798 - val_loss: 0.4442 - val_acc: 0.7828
# Epoch 3/50
# ...
# 128/157 [=======================>......] - ETA: 48s - loss: 0.4346 - acc: 0.7890
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e646b9b59311> in <module>()
#      76     workers=4,
#      77     validation_data=validation_generator,
# ---> 78     validation_steps=validation_generator.samples // batch_size)
#      79
#      80 #model.save_weights('/content/drive/KerasDeepNet/CatsDogs/first_try.h5')
#
# ...

# %%
#import site; 
#site.getsitepackages()

# !ls /usr/lib/python3/dist-packages/__pycache__
# Out:
# lsb_release.cpython-36.pyc
# ls: cannot access '/usr/lib/python3.6/dist-packages/': No such file or directory

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# Next, we will preprocess our image data before supplying it to the training model.

# %%
from tqdm import tqdm
def read_img(img_path):
    img = cv2.imread(img_path)
    img = cv2.resize(img, (128, 128))
    return img

# %% [markdown]
# The above function reads an image and resizes it to 128 x 128 dimensions and returns it.

# %%
train_img = []
for img_path in tqdm(train.Image_name.values):
    train_img.append(read_img(TRAIN_PATH + img_path))
# Out:
# 100%|██████████| 12600/12600 [02:49<00:00, 74.37it/s]

# %%
import gc

# %%
# Convert the image data into an array. 
# Since the range of color(RGB) is in the range of (0-255).
# Hence by dividing each image by 255, we convert the range to (0.0 - 1.0)

X_train = np.array(train_img, np.float32) / 255.

# %%
del train_img
gc.collect()
# Out:
# 19117

# %% [markdown]
# Next, we will calculate the mean and standard deviation.

# %%
mean_img = X_train.mean(axis=0)

# %%
std_dev = X_train.std(axis = 0)

# %% [markdown]
# Next, we will normalize the image data using the following formula: **X = (x - mean of x)/(std. deviation of x)**

# %%
X_norm = (X_train - mean_img)/ std_dev

# %%
X_norm.shape
# Out:
# (12600, 128, 128, 3)

# %%
del X_train

# %%
gc.collect()
# Out:
# 0

# %%
y = train[label_cols].values

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Finally, we create the training and validation sets.

# %%
Xtrain, Xvalid, ytrain, yvalid = train_test_split(X_norm, y, test_size=0.25, random_state=47)

# %%
print(Xtrain.shape)
del X_norm
gc.collect()
# Out:
# (9450, 128, 128, 3)
# 421

# %% [markdown]
# # **Model Architecture**

# %% [markdown]
# We will be using the Keras framework to create our model. But you may also use other frameworks like Tensorflow, Pytorch, etc.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# For this problem, we create a model from scratch. We will use a Sequential model, which is a linear stack of layers to build this model.

# %%
gc.collect()

# %%
model = Sequential()
model.add(BatchNormalization(input_shape=Xtrain.shape[1:]))
model.add(Conv2D(32, kernel_size=(3, 3), activation= 'relu'))

model.add(Conv2D(64, kernel_size=(3, 3), activation= 'relu', padding='same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation= 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), activation= 'relu', padding='same'))
model.add(Conv2D(128, kernel_size=(3, 3), activation= 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(85, activation='sigmoid'))

# %% [markdown]
# Here we generate the summary our model. We can see that there are approximately 10 million parameters to train.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# batch_normalization_1 (Batch (None, 128, 128, 3)       12
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 126, 126, 64)      18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 124, 124, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 62, 62, 128)       73856
# ...

# %% [markdown]
# Next, we define our loss function, the optimizer and metrics for our model.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stops = EarlyStopping(patience=3, monitor='val_acc')
checkpointer = ModelCheckpoint(filepath='weights.best.eda.hdf5', verbose=1, save_best_only=True)

# %% [markdown]
# Finally, we train our model.

# %%
model.fit(Xtrain, ytrain, validation_data=(Xvalid, yvalid), epochs=3, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 9450 samples, validate on 3150 samples
# Epoch 1/3
# 9450/9450 [==============================] - 96s 10ms/step - loss: 0.4643 - acc: 0.7710 - val_loss: 0.4393 - val_acc: 0.7836
#
# Epoch 00001: val_loss improved from inf to 0.43930, saving model to weights.best.eda.hdf5
# Epoch 2/3
# ...
# 9450/9450 [==============================] - 93s 10ms/step - loss: 0.4292 - acc: 0.7910 - val_loss: 0.4229 - val_acc: 0.7964
#
# Epoch 00002: val_loss improved from 0.43930 to 0.42287, saving model to weights.best.eda.hdf5
# Epoch 3/3
# ...
# 9450/9450 [==============================] - 93s 10ms/step - loss: 0.4014 - acc: 0.8078 - val_loss: 0.4102 - val_acc: 0.8049
#
# Epoch 00003: val_loss improved from 0.42287 to 0.41016, saving model to weights.best.eda.hdf5

# %%
train_pred = model.predict(Xtrain).round()

# %%
from sklearn.metrics import f1_score
f1_score(ytrain, train_pred, average='samples')
# Out:
# 0.7652767430322258

# %%
valid_pred = model.predict(Xvalid).round()

# %%
f1_score(yvalid, valid_pred, average='samples')
# Out:
# 0.7224794046840541

# %%
#del Xtrain
#del Xvalid
#del ytrain 
#del yvalid
gc.collect()

# %% [markdown]
# # **Prediction on Test Set**

# %% [markdown]
# Now that we have built and trained our model, we will use it to predict the labels of the test images.

# %%
from sklearn.metrics import f1_score

# %%
test_img = []
for img_path in tqdm(test.Image_name.values):
    test_img.append(read_img(TEST_PATH + img_path))
# Out:
# 100%|██████████| 5400/5400 [01:12<00:00, 74.74it/s]

# %%
X_test = np.array(test_img, np.float32) / 255.

# %%
del test_img
gc.collect()
# Out:
# 0

# %% [markdown]
# The test images are normalized below.

# %%
mean_img = X_test.mean(axis=0)

# %%
std_dev = X_test.std(axis = 0)

# %%
X_norm_test = (X_test - mean_img)/ std_dev

# %%
del X_test
gc.collect()
0
# Out:
# 0

# %% [markdown]
# Predict the labels on the test images.

# %%
model.load_weights('weights.best.eda.hdf5')

# %%
pred_test = model.predict(X_norm_test).round()

# %%
pred_test = pred_test.astype(np.int)

# %% [markdown]
# # **Creating the submission file**

# %%
subm = pd.DataFrame()

# %%
subm['Image_name'] = test.Image_name

# %%
label_df = pd.DataFrame(data=pred_test, columns=label_cols)
#print(label_df)

# %%
subm = pd.concat([subm, label_df], axis=1)
#print(subm)

# %%
subm.to_csv('submit.csv', index=False)
